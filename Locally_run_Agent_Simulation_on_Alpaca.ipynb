# %% [markdown]
# <a href="https://colab.research.google.com/github/SnowyGanyu/Goblin/blob/main/Locally_run_Agent_Simulation_on_Alpaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 63.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 109.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.1 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from transformers import pipeline

access_token = "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"

prompt = "Write an message about how computers are best for gaming"
model = pipeline(model="declare-lab/flan-alpaca-large", device=0)
model(prompt, max_length=128, do_sample=True)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/787 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [{'generated_text': 'Computers are the best way to play games, so invest in high-quality hardware and software. Investing in gaming hardware will help you to stay ahead of the competition and experience greater gaming speeds. Computers can also be used for other uses such as work, entertainment, or education. No matter the gaming activity, make sure to get the best quality hardware available—there are plenty of gaming peripherals out there.'}]

# %%
from transformers import pipeline
import networkx as nx
prompt = '''### Instruction:
Who is the first person on the moon?

### Response '''
def generate(prompt):
  output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
  out = output[0]['generated_text']
  if '### Reponse:' in out:
    out = out.split('### Response: ')[1]
  if '### Instruction:' in out:
    out = out.split('### Instruction:')[0]
  return out

# %%
world_graph = nx.Graph()

prompt_meta = '''### Instruction:
{}

### Response:'''

city_areas = ["Barthen's Provisions", "Lionshield Coster", "Stonehill Inn", "Phandalin Town Square"]
city_areas = {"Phandalin Town Square": 'Town square of the town of Phandalin.',
              'Stonehill Inn': "In the center of town stands a large, newly built roadhouse of fieldstone and rough-hewn timbers. The common room is filled with locals nursing mugs of ale or cider, all of them eyeing you with curiosity.",
              "Barthen's Provisions": "Barthen’s is the biggest trading post in Phandalin. Its shelves stock most ordinary goods and supplies, including backpacks, bedrolls, rope, and rations. The place is open from sunup to sundown.",
              "Edermath Orchard": "A tidy little cottage beside an apple orchard.",
              "Lionshield Coster": "Hanging above the front door of this modest trading post is a sign shaped like a wooden shield with a blue lion painted on it. This building is owned by the Lionshields, a merchant company based in the city of Yartar, over a hundred miles to the east. They ship finished goods to Phandalin and other small settlements throughout the region, but this outpost has been hard hit by banditry. The most recent Lionshield caravan due in Phandalin never arrived.",
              "Phandalin Miner's Exchange": "The Miner’s Exchange is a trading post where local miners have their valuable finds weighed, measured, and paid out. In the absence of any local lord or authority, the exchange also serves as an unofficial records office, registering claims to various streams and excavations around the area. There isn’t any real gold rush in Phandalin, but enough wealth is hidden in the nearby streams and valleys to support a good number of independent prospectors. The exchange is a great place to meet people who spend a lot of time out and about in the countryside surrounding Phandalin. The guildmaster is an ambitious and calculating human woman named Halia Thornton.",
              "Alderleaf Farm": "A farm owned by the helpful halfling farmer, Qelline Alderleaf.",
              "Shrine of Luck": "Phandalin's only temple is a small shrine made of stones taken from the nearby ruins. It is dedicated to Tymora, goddess of luck and good fortune.",
              "The Sleeping Giant": "This rundown tap house is a dirty, dangerous watering hole at the end of Phandalin’s main street. It is frequented by Redbrand thugs and operated by a surly female dwarf named Grista.",
              "Townmaster’s Hall": "The townmaster’s hall has sturdy stone walls, a pitched wooden roof, and a bell tower at the back. Posted on a board next to the front door is a notice written in Common. It reads: “REWARD — Orcs near Wyvern Tor! Those of a mind to face the orc menace should inquire within.” The notice bears the town’s seal and an indecipherable signature.",
              "Tresendar Manor": "A ruined manor. The Redbrands’ base in Phandalin is a dungeon complex under Tresendar Manor. Before the manor was ruined, its cellars served as safe storage for food and water in the event that the estate was attacked, while an adjoining crypt provided a resting place for the deceased members of the Tresendar family. The Redbrands have since expanded the cellars to suit their own purposes, adding slave pens, workshops, and barracks."
              }
city_folk = {"Toblen Stonehill": "Toblen owns a trading post.",
               "Daran Edermath": "Daran is a retired adventurer who lives in a tidy little cottage beside an apple orchard. A fit, silver-haired half-elf well over a hundred years old, Daran is a fighter who served as a marshal and herald for many years in the lands of the Dragon Coast, far to the southeast. Upon retiring, he returned to the Neverwinter region, his original home.",
               "Linene Graywind": "Linene runs a trading post.",
               "Halia Thornton": "Halia is an ambitious and calculating human woman. She is the guildmaster of Phandalin Miner’s Exchange, a trading post where local miners have their valuable finds weighed, measured, and paid out. In her attempts to establish the Miner's Exchange as the closest thing the town has to a governing authority, she acts as more than a simple merchant.",
               "Qelline Alderleaf": "Qelline is a wise female halfling of forty-five, and is a pragmatic farmer who seems to know everything that goes on in town. She is a kind host, and is willing to let the characters stay in her hayloft if they don't want to stay at the Stonehill Inn.",
               "Sister Garaele": "Sister Garaele is an elf cleric of Tymora and a Harper agent.",
               "Harbin Wester": "Harbin is the townmaster of Phandalin. A pompous, old food. Phandalin has no functioning government, but the townsfolk elect someone to serve as townmaster each year. The townmaster serves as a judge in minor disputes and keeps any records that need to be kept.",
               "Terrill Bloodscar": "Terrill is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Conrad Scarface": "Conrad is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               "Nellie Starsmith": "Nellie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               "Valerie Grinblade": "Valerie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               }
for city_area in city_areas.keys():
  world_graph.add_node(city_area)
  world_graph.add_edge(city_area, city_area)
for city_area in city_areas.keys():
  world_graph.add_edge(city_area, "Phandalin Town Square")
locations = {}
for i in city_folk.keys():
  locations[i] = "Phandalin Town Square"


memories = {}
for i in city_folk.keys():
  memories[i] = []
plans = {}
for i in city_folk.keys():
  plans[i] = []

global_time = 8
def generate_description_of_area(x):
  text = "It is "+str(global_time)+":00. The location is "+x+"."
  people = []
  for i in locations.keys():
    if locations[i] == x:
      people.append(i)

# %%
compressed_memories_all = {}
for name in city_folk.keys():
  compressed_memories_all[name] = []

# %%
for name in city_folk.keys():
  prompt = "You are {}. {} You just woke up in the town of Phandalin and went out to the Town Square. The following people live in the town: {}. What is your goal for today? Be brief, and use at most 20 words and answer from your perspective.".format(name, city_folk[name], ', '.join(list(city_folk.keys())) )
  plans[name] = generate(prompt_meta.format(prompt))
  print(name, plans[name])
# Out:
# Toblen Stonehill Toblen Stonehill's goal is to sell all the goods in the trading post to the people of the town.
# Daran Edermath Setting a goal to find a friend in town.
# Linene Graywind Linene Graywind: I plan to shop in town tomorrow.
# Halia Thornton My goal today is to establish Phandalin Miner's Exchange as the closest thing to a governing authority.
# Qelline Alderleaf Qelline Alderleaf has a goal of making sure everyone is in the Stonehill Inn.
# Sister Garaele My goal for today is to meet the people in Phandalin and establish a strong alliance with Harbin Wester and Terrill Bloodscar.
# Harbin Wester Discover Phandalin. Today I want to make the most of my journey by absorbing the rich culture and traditions of Phandalin in order to become the townmaster in charge.
# Terrill Bloodscar My goal for today is to rob innocent people.
# Conrad Scarface My goal today is to be the leader of the Redbrand ruffians to rob and kill a few adventurers.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Nellie Starsmith Nellie Starsmith: Take on adventurers as part of the Redbrand ruffians.
# Valerie Grinblade Toblen Stonehill and Harbin Wester are here to join in the action.

# %%
action_prompts = {}
for location in city_areas.keys():
  folk = []
  for i in city_folk.keys():
    if locations[i] == location:
      folk.append(i)

  for name in folk:
    prompt = "You are {}. {} You are planning to: {}. You are currently in {} with the following description: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, city_folk[name], plans[name], location, city_areas[location], str(global_time), ', '.join(folk))
    folk_description = []
    for i in folk:
      folk_description.append(i+': '+city_folk[i])
    prompt += ' You know the following about people: ' + '. '.join(folk_description)
    memory_text = '. '.join(memories[name][-10:])
    prompt += "What do you do in the next hour? Use at most 10 words to explain."
    action_prompts[name] = prompt

# %%
action_results = {}
for name in city_folk.keys():
  action_results[name] = generate(prompt_meta.format(action_prompts[name]))
  # Now clean the action
  prompt = """
  Convert the following paragraph to first person past tense:
  "{}"
  """.format(action_results[name])
  action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
  print(name, action_results[name])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (853 > 512). Running this sequence through the model will result in indexing errors
# Toblen Stonehill I sold all the goods in the trading post.
# Daran Edermath I was looking for a friend in town and doing my best to find a way to make a connection with the villagers.
# Linene Graywind I plan to shop in town tonight. ###
# Halia Thornton By the time I was seeking to establish Phandalin Miners Exchange as the closest thing to a governing authority.
# Qelline Alderleaf Qellin Alderleaf set out to make sure that everyone was in the Stonehill Inn.
# Sister Garaele I set an alliance with Harbin Wester and Terrill Bloodscar. I explored the town. I learned from them. I connected with them. I worked to reassure heirs. I spoke to them. I listen to their voices. I became closer to them. I had fun.
# Harbin Wester Harbin Wester: Ill meet the players and get a better understanding of their culture and traditions.
# Terrill Bloodscar Terrill Bloodscar planned to rob innocent people in Phandalin Town Square.
# Conrad Scarface Conrad Scarface made an effort to rob and kill the adventurers.
# Nellie Starsmith I was planning to confront Adventurers.
# Valerie Grinblade The local ruffians need to join forces in Phandalin Town Square to protect their territory from the Redbrand ruffians and to protect their own home and family.

# %%
action_prompts = {}
for location in city_areas.keys():
  folk = []
  for i in city_folk.keys():
    if locations[i] == location:
      folk.append(i)

  for name in folk:
    for name_two in folk:
      memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

# %%
import re
def get_rating(x):
  nums = [int(i) for i in re.findall(r'\d+', x)]
  if len(nums)>0:
    return min(nums)
  else:
    return None

# %%
memory_ratings = {}
for name in city_folk.keys():
  memory_ratings[name] = []
  for i, memory in enumerate(memories[name]):
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], locations[name], str(global_time), memory)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    memory_ratings[name].append((res, rating))
  print(memory_ratings[name])
# Out:
# [("1 rating. I have not seen toblen Stonehill for some time now and am not sure if he is currently selling items, but he's got the potential to buy those items for later on.", 1), ("1/5. This is a really good way to learn more about Daran. I can't believe he's in town and doing something so meaningful to the town.", 1), ('5 with a score of 5 out of 5', 5), ('4/5. It would be interesting to create a trading post in Phandalin at that time.', 4), ('4th. Toblen Stonehill is trying to get all the goods in his trading post to people.', 4), ('5/5. This plan is very much of a priority for me.', 5), ("5 because I'm eager to learn more about the local culture and traditions.", 5), ('5 out of 10. My rating for this is 2.', 2), ('8-5. Toblen Stonehill cares about this because it will make it easier for him to achieve his goal of selling all the goods in the trading post to the people of the town. This is good because it will remind Toblen Stonehill and his friends who he was trying to rob and kill the adventurers important details that he needs to remember.', 5), ('3/5. Toblen Stonehill is a good leader and has a good plan to reach his goal.', 3), ('3 and I am concerned about this as it would be detrimental', 3)]
# [("2 stars. Since I'm a stranger and I'm unable to remember who I was to Toblen Stonehill, I was wondering if I could help.", 2), ('We are delighted to learn that Daran Edermath is setting a goal of finding a friend in Phandalin Town Square. Please give him my highest rating of 5/5 stars!', 5), ('5 and I would rate this 5 as being very important since I am currently in Phandalin Town Square.', 5), ('4/5. This is a great way to meet someone in the town who you share a common interest.', 4), ('1 out of 5 - I am very grateful for the help.', 1), ('1/5. Daran Edermath is determined to make it to Sister Garaele and find a friend that enjoys the same activities as when he was in the town.', 1), ('4 (It is high time to meet a friend in town)', 4), ('4/5. We should take action soon to confront Terrill Bloodscar and prevent further crimes.', 4), ("3/5. I'm worried about the consequences that the current situation will bring if I don't find a friend in town.", 3), ("4 stars. It's time to meet Nellie Starsmith in Phandalin Town Square.", 4), ("I love this area and I can't wait to get to know some new people.", 0)]
# [('2/5. Linene Graywind is quite interested in seeing what Toblen Stonehill has seen lately. He mentions the fact that he has sold all the goods in the trading post.', 2), ('3-4 stars. Linene Graywind is excited to make a friend in town tomorrow.', 3), ('4 out of 5. This is too important to ignore. There are lots of other things to do and experience at Phandalin Town Square that I had better take the time to explore.', 4), ('3/5. I am looking forward to going shopping.', 3), ('3: I am not as enthusiastic about this as I first thought.', 3), ('5 out of 5. It is truly enjoyable to learn together and share together.', 5), ('2/5. I am satisfied with the information.', 2), ('5: I am very concerned about the situation in Phandalin Town Square.', 5), ('3/5. The movie was good, but the story was somewhat tedious and non-existent.', 3), ('5-4. Linene Graywind is not particularly pleased with this.', 4), ('4: I am concerned about the safety and security of our local ruffians.', 4)]
# [("4/5. I really enjoy setting up the Phandalin Miner's Exchange to ensure it is a successful and accountable organization.", 4), ('3/5. I am very interested in connecting with Daran and am curious if there is anything he can offer in exchange for me setting up some kind of governing authority. He is one of the best options available.', 3), ("4/5. I am a passionate individual who values the idea of setting up Phandalin Miner's Exchange as the closest thing to a governing authority.", 4), ("4/5. I am very interested in helping Phandalin Miner's Exchange be a governing authority.", 4), ('5/Baywatch.Halia Thornton.', 5), ("4/5. I'm excited about establishing Phandalin Miner's Exchange as the closest thing to a governing authority.", 4), ("5 out of 5. Very interested in attending Harbin Wester's meeting, and looking forward to learning more about the players.", 5), ('3/5. I would rate this an 4/5.', 3), ("4 out of 5 ###.I am happy that my goal of establishing Phandalin Miner's Exchange as the closest thing to a governing authority is coming to fruition.This leads us to being motivated to work together and make sure things move along smoothly.I am confident that our efforts will result in a successful outcome.", 4), ("1/5. I am very motivated to achieve my goal of setting up Phandalin Miner's Exchange as the closest thing to a governing authority today.", 1), ('8 out of 10. I would rate this 8 out of 10. Valerie Grinblade is the strongest advocate against the Redbrand ruffians. She recites the fight plan and will gladly join forces to protect my town and my family. The local ruffians are always fighting for their rights and I look forward to helping them take control of Phandalin Town Square.', 8)]
# [('4/5. Qelline Alderleaf cares very much about this as it influences her decision-making process.', 4), ("4/9 and 2/5. It's important to make it to Stonehill Inn.", 2), ('10/8 for the accuracy of the information, but the accuracy between 8 and 7 is inconsistent. Linene Graywind is making the time difference, and if Qelline needs to look for Linene to confirm, she should look for her in town or call it in.', 7), ('5 ### Qelline Alderleaf.', 5), ('3/5. I am very interested in this and it is a critical priority for me.', 3), ("5 ### ### Qelline Alderleaf's rating is 5.", 5), ('4. It is important for everyone to be in the Stonehill Inn.', 4), ('5 with a rating of 3 to 5: Qelline Alderleaf is deeply concerned by this situation and her plans to ensure everyone is in the Stonehill Inn, which she had in mind.', 3), ('3/5. I strongly want to make sure everyone has arrived at the Stonehill Inn before they leave.', 3), ('3/5. No worries. I think I can make it.', 3), ('3/5. I am excited for the fight to come to a successful conclusion. I value the time to be able to join forces to protect the local ruffians and their home and family. The Stonehill Inn is one of the most important resources for the local ruffians.', 3)]
# [('4/5. I am in high demand and would like to be able to meet and connect with the people around Phandalin.', 4), ('3 stars. My goal is to form a strong alliance with Harbin Wester and Terrill Bloodscar.', 3), ('4/5. This is important to me. I believe this plan will help me with establishing a strong alliance with Harbin Wester and Terrill Bloodscar.', 4), ('5/5. You have done a great job setting your expectations and achieving your goals.', 5), ('4/ 5 * Qellin Alderleaf cares about keeping everyone safe in the Stonehill Inn.', 4), ('4/5 because the association and learnings from the meeting makes me want to go further.', 4), ("4/5. Having her share of knowledge on the local culture and traditions is highly helpful in understanding the players' needs and concerns.", 4), ('3.4. I am concerned about this.', 3), ('4/5. Please continue to make sure to keep that information about Conrad Scarface in your mind and make sure to keep a safe distance from the adventurers while they are at Phandalin Town Square', 4), ("3/5. It's important to have a plan in place, so that I can plan my strategy and execute it successfully.", 3), ('10 because I truly care about this. It is an essential resource to keep the local ruffians safe from the Redbrand ruffians and their forces.', 10)]
# [('1 since it is now 8 . I am interested to learn more about Phandalin.', 1), ('5/5. It is very interesting to observe Daran Edermath taking the time to make a connection with villagers. He is an engaging and knowledgeable individual who seems to be eager to make an impact in Phandalin.', 5), ('3/5. I am interested in the plan because it will help me take advantage of this opportunity to explore Phandalin and become the townmaster in charge.', 3), ('I am very interested in learning Phandalin and its history.', 0), ("4 and 5 rated. As I'm exploring Phandalin, I observe that the time is 8 + 7 and the person is Qelline Alderleaf, the townmaster of Phandalin.", 4), ('4 (Sister Garaele is caring)', 4), ('4/5. Harbin Wester cares about his trip to Phandalin.', 4), ("3/5. I would rate this 4/5 if it wasn't for the incident it could have been worse.", 3), ("4: I take Conrad Scarface's intentions very seriously and can understand why they are trying to get a hold of adventurers.", 4), ("3 (5 out of 5). Harbin Wester is an ambitious person with great ambition, aiming to become the townmaster of Phandalin. He is passionate about Phandalin's culture and traditions, and loves the opportunity to be a part of it. He would love to learn about the culture and traditions of Phandalin and work for their advancement, and to become the townmaster in charge.", 3), ('3/0. I am satisfied with the situation.', 0)]
# [('4 and I think the person is very brave to risk his life to try and stop Terrill from committing a crime.', 4), ('4/10. [I value this experience highly and understand the risks associated with it.]', 4), ('5/5. I would rather rob innocent people than engage in the action of robbery.', 5), ('5/5. Terrill Bloodscar is worried not only that the clocks have already moved, but that he will be caught by an innocent man who has just lost the money from the pimp he hired. This could potentially result in disaster.', 5), ('3/6. Qellin Alderleaf was right.', 3), ("3/5. This is not a problem for me because it is not very important for me to make it through today: it's irrelevant to my plan.", 3), ('3/5. Harbin Wester should be appreciative for his visit.', 3), ("5: It would be helpful to have a bit more detail about Terrill's plans such as the time, place and purpose of the crime.", 5), ("4 out of 5. My favorite part of this exercise is knowing so much about Conrad Scarface's planning.", 4), ("5 This is very concerning, as it implies that Nellie Starsmith would be safe and the plan to confront Adventurers would be a violation of Terrill's plans and possibly the lives of many people.", 5), ('5 out of 5. Despite the warning of Valerie Grinblade, I am still deeply concerned about the situation.', 5)]
# [("4/5. Taking advantage of Toblen Stonehill's help is important in order to reach your goal.", 4), ('2/5. Conrad Scarface is looking for friends in town and trying to find a way to make a connection with the villagers.', 2), ("1 rating. I don't think I care much about this, as it's not my 'real' time.", 1), ('5 to my review. I believe Halia Thornton is a good person and understands my purpose and the need for Phandalin Miners Exchange. She is making sure that Phandalin Miners Exchange can serve as its main authority, and that I can be an effective leader of the Redbrand ruffians.', 5), ('4/5. You should know more about this beforehand.', 4), ('4 / 5 and to remember the things that really did reassure them', 4), ("2 or 3/5. I'm very interested in learning more about the players and their culture and traditions.", 2), ('5 because this tells me that my goal is to be the leader of the Redbrand ruffians to rob and kill a few adventurers.', 5), ('1/5. I am not quite sure about the outcome yet.', 1), ("5 - I'm very confident in my plan and will carry it out to the fullest", 5), ('3/4. The local ruffians could use an infusion of strength and courage to fight the Redbrand ruffians and protect their home and family.', 3)]
# [('The most important factor in the evaluation of this task is whether you are willing to take on the Redbrand ruffians, as a Redbrand she is likely to be willing to use her skills and knowledge to help the Redbrand ruffians defeat any adversaries.', 0), ('2/5. I am incredibly excited to have Daran as my new friend. He understands my goals, has a great plan to explore the city, and is willing to help in any way.', 2), ('3/5. Nellie Starsmith cares about this. She will continue to take on the adventurers and help the Redbrand ruffians.', 3), ('3/5. This is a good indication of how much Nellie enjoys the Redbrand ruffians mission and the goals she hopes to achieve.', 3), ('3/5. Qellin Alderleaf should be commended for her task of setting up the Stonehill Inn before Nellie Starsmith arrived.', 3), ('5/5. It is a success and it shows that it is achievable in a short amount of time.', 5), ("5 stars, because I'm genuinely interested in having Harbin Wester meet the redbrand ruffians and learn about their culture and traditions.", 5), ('I would give this a rating of 4, as I am very concerned about this situation.', 4), ('3/5. This is very important to me now.', 3), ('4 stars. I believe Nellie Starsmith puts her skills and experience to good use.', 4), ('4/5. (This is a critical step for protecting Phandalin Town Square.)', 4)]
# [("4/5. The details of Toblen Stonehill's memory of selling all the goods in the trading post, such as time and location, are of great interest. This could indicate that Toblen is taking advantage of having to stay in Phandalin and wait for his friends to return.", 4), ('10 - Valerie Grinblade and Toblen Stonehill have enjoyed the experience immensely and have been eager to join in the action.', 10), ('4/ 5. This is a really important detail and it shows that Valerie has an interest in the shop.', 4), ('4 / 5 rating on this task.', 4), ('4/5. Valerie Grinblade is very interested in the plan and is concerned about the safety of her friends. She is worried about the time change and the situation in town square.', 4), ('5 to 5. I am interested in this action mainly because it will bring together my allies Harbin Wester and Terrill Bloodscar.', 5), ("3/5. *Harbin Wester is excited to get to know the players and learn more about them's culture and traditions. *Toblen Stonehill and Harbin Wester are excited too. *He’ll be able to understand the culture and traditions of their hometown while spending time with them.", 3), ('4 (Not at all). It is very interesting to observe and I am sure that I will see some action from the three of us. I agree with Toblen Stonehill and Harbin Wester about putting in their resources to help.', 4), ('a). - 5 b).', 5), ('3/5. Nellie Starsmith is a member of the Adventurers group and she plans to confront them.', 3), ("4 (0). Valerie Grinblade's attitude towards the situation is quite strong and she would appreciate it if her friend Harbin Wester could join in.", 0)]

# %%
MEMORY_LIMIT = 10
compressed_memories = {}
for name in city_folk.keys():
  memories_sorted = sorted(
        memory_ratings[name],
        key=lambda x: x[1]
    )[::-1]
  relevant_memories = memories_sorted[:MEMORY_LIMIT]
  # print(name, relevant_memories)
  memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
  prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
  res = generate(prompt_meta.format(prompt))
  compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
  compressed_memories_all[name].append(compressed_memories[name])

# %%
place_ratings = {}

for name in city_folk.keys():
  place_ratings[name] = []
  for area in city_areas.keys():
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    place_ratings[name].append((area, rating, res))
  place_ratings_sorted = sorted(
      place_ratings[name],
      key=lambda x: x[1]
  )[::-1]
  if place_ratings_sorted[0][0] != locations[name]:
    new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
    compressed_memories_all[name].append(new_recollection)
  locations[name] = place_ratings_sorted[0][0]

# %%
for repeats in range(5):
  global_time += 1
  action_prompts = {}
  for location in city_areas.keys():
    folk = []
    for i in city_folk.keys():
      if locations[i] == location:
        folk.append(i)

    for name in folk:
      prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. Your memories are: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, city_areas[location], '\n'.join(compressed_memories_all[name][-5:]), str(global_time), ', '.join(folk))
      folk_description = []
      for i in folk:
        folk_description.append(i+': '+city_folk[i])
      prompt += ' You know the following about people: ' + '. '.join(folk_description)
      memory_text = '. '.join(memories[name][-10:])
      prompt += "What do you do in the next hour? Use at most 10 words to explain."
      action_prompts[name] = prompt
  action_results = {}
  for name in city_folk.keys():
    action_results[name] = generate(prompt_meta.format(action_prompts[name]))
    # Now clean the action
    prompt = """
    Convert the following paragraph to first person past tense:
    "{}"
    """.format(action_results[name])
    action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print(name, locations[name], global_time, action_results[name])
  action_emojis = {}
  for name in city_folk.keys():
    prompt = """
    Convert the following paragraph to a tuple (Action, Object):
    "{}"
    """.format(action_results[name])
    action_emojis[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print('    - Emoji Representation:', name, locations[name], global_time, action_emojis[name])
  action_prompts = {}
  for location in city_areas.keys():
    folk = []
    for i in city_folk.keys():
      if locations[i] == location:
        folk.append(i)

    for name in folk:
      for name_two in folk:
        memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

  memory_ratings = {}
  for name in city_folk.keys():
    memory_ratings[name] = []
    for i, memory in enumerate(memories[name]):
      prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      memory_ratings[name].append((res, rating))

  compressed_memories = {}
  for name in city_folk.keys():
    memories_sorted = sorted(
          memory_ratings[name],
          key=lambda x: x[1]
      )[::-1]
    relevant_memories = memories_sorted[:MEMORY_LIMIT]
    memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
    res = generate(prompt_meta.format(prompt))
    compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
    compressed_memories_all[name].append(compressed_memories[name])

  place_ratings = {}

  for name in city_folk.keys():
    place_ratings[name] = []
    for area in city_areas.keys():
      prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      place_ratings[name].append((area, rating, res))
    place_ratings_sorted = sorted(
        place_ratings[name],
        key=lambda x: x[1] )[::-1]
    if place_ratings_sorted[0][0] != locations[name]:
      new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
      compressed_memories_all[name].append(new_recollection)
    locations[name] = place_ratings_sorted[0][0]
# Out:
# Toblen Stonehill The Sleeping Giant 9 I tried to take advantage of the towns abundant resources. I also used my trading post to expand my trading empire - e.g. selling the goods that would make up the Phandalin Miners Exchange for the town. I would like to make this dream a reality by selling the goods and letting it do the talking.
# Daran Edermath Lionshield Coster 9 I plan to explore the town and meet his friends in a quiet place.
# Linene Graywind Phandalin Miner's Exchange 9 I was at 11 p.m.
# Halia Thornton The Sleeping Giant 9 Toblen Stonehill: I was planning to take the opportunity to talk to Halia Thornton in the next hour. Qelline Alderleaf: I was inviting Halia Thornton and her friends to stay in my hayloft. Toblen Stonehill: Heres the plan for tonight. [This was the plan from the night before]
# Qelline Alderleaf The Sleeping Giant 9 Qelline Alderleaf met Toblen Stonehill, Halia Thornton and Qelline Alderleaf together they thought to find out at the Stonehill Inn and join the fight to save the town.
# Sister Garaele Edermath Orchard 9 I made a strength-based team that could combat the Redbrands strategies and create an alliance together.
# Harbin Wester Townmaster’s Hall 9 I confronted Conrad Scarface to learn more about the culture of Phandalin.
# Terrill Bloodscar Edermath Orchard 9 I ran into innocent people who had been slain.
# Conrad Scarface Townmaster’s Hall 9 I followed Harbin Wester for the remaining hours of the day.
# Nellie Starsmith Phandalin Town Square 9 I Rob and killed adventurers for the Redbrand Ruffians.
# Valerie Grinblade Barthen's Provisions 9 I was trying to join the action at Barthens Provisions with Toblen Stonehill and Harbin Wester.
#     - Emoji Representation: Toblen Stonehill The Sleeping Giant 9 [adjective, object] - I tried - used - trading post - expanded Object: Phandalin Miners Exchange
#     - Emoji Representation: Daran Edermath Lionshield Coster 9 Action A plan to explore the town Exploratorium and meet his friends Object quiet place
#     - Emoji Representation: Linene Graywind Phandalin Miner's Exchange 9 Object: I Was.action: was Object: 10
#     - Emoji Representation: Halia Thornton The Sleeping Giant 9 Action, ActionAction, Object Action, Object, Action, Object, Object, Object A. Talk to Halia Thornton B. Invite Halia Thornton and her friends C. Show Heres the plan for tonight D. Tell this the plan from the night before E. Plan for tonight.
#     - Emoji Representation: Qelline Alderleaf The Sleeping Giant 9 Action Meeting  Toblen Stonehill, Halia Thornton, Qelline Alderleaf, Together  Join the fight  Find out at the Stonehill Inn  Join the fight to save the town
#     - Emoji Representation: Sister Garaele Edermath Orchard 9 Action: make strength-based team Object: combat the Redbrands strategies
#     - Emoji Representation: Harbin Wester Townmaster’s Hall 9 Question, Conrad Scarface. Answer, Knowledge about Phandalin culture is an essential part of many cultures around the world. .
#     - Emoji Representation: Terrill Bloodscar Edermath Orchard 9 Action: ran into object: innocent people who had been slain
#     - Emoji Representation: Conrad Scarface Townmaster’s Hall 9 I followed Harbin Wester for the remaining hours of the day.
#     - Emoji Representation: Nellie Starsmith Phandalin Town Square 9 Action: Rob Object: Adventurers for the Redbrand Ruffians Action: killed Object: None
#     - Emoji Representation: Valerie Grinblade Barthen's Provisions 9 [I joined the action at Barthens Provisions with Toblen Stonehill and Harbin Wester.)
# Toblen Stonehill Tresendar Manor 10 I set up a suitable shopping location for my customers.
# Daran Edermath Edermath Orchard 10 I set a goal in the next hour and found a friend.
# Linene Graywind Townmaster’s Hall 10 Lynne Graywind: I looked forward to tomorrow.
# Halia Thornton Phandalin Miner's Exchange 10 Neither did I visit Qelline Alderleaf in the next hour.
# Qelline Alderleaf Phandalin Miner's Exchange 10 Qelline Alderleaf: I brought everyone to the Stonehill Inn
# Sister Garaele Barthen's Provisions 10 I will join Harbin Wester and Terrill Bloodscar in exploring Phandalin.
# Harbin Wester Stonehill Inn 10 I explored Phandalin to gain more knowledge.
# Terrill Bloodscar Townmaster’s Hall 10 I talked to Terrill Bloodscar who will confront the adventurers at Townmaster’s Hall and rob an innocent people.
# Conrad Scarface Phandalin Town Square 10 I was an masked ruffian from the town of Phandalin who plans to hijack a few adventurers and rob them of their treasure and fortune. Isnt this a part of your plan? Its time to act and make this a successful day.
# Nellie Starsmith Lionshield Coster 10 I rejected danger and thwarted the heiress.
# Valerie Grinblade Tresendar Manor 10 He reached the upper chamber and explored it.
#     - Emoji Representation: Toblen Stonehill Tresendar Manor 10 [Action + Object] Set up suitable shopping location ###
#     - Emoji Representation: Daran Edermath Edermath Orchard 10 Action: Set a goal In the next hour Object: Found a friend
#     - Emoji Representation: Linene Graywind Townmaster’s Hall 10 Action: watched Object Object: Tomorrow
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 10 Action, Object: Neither visited Qelline Alderleaf => Action >> Neither did I visit Qelline Alderleaf in the next hour >> Action >> Neither didn I visit Qelline Alderleaf in the first hour >> Action >> Neither did I visit Qelline Alderleaf in the second hour => Action >> Neither did I visit Qelline Alderleaf in the first hour >> Action >> Neither did I visit Qelline Alderleaf in the second hour >> Action >> Neither visited Qelline Alderleaf in the first hour >> Action >> Neither did I visit Qelline Alderleaf in the second hour >> Action >>
#     - Emoji Representation: Qelline Alderleaf Phandalin Miner's Exchange 10 Qelline Alderleaf action: brought everyone to the Stonehill Inn Object: Stonehill Inn
#     - Emoji Representation: Sister Garaele Barthen's Provisions 10 I Will Join Harbin Wester and Terrill Bloodscar in Exploring Phandalin. [Action, Object]
#     - Emoji Representation: Harbin Wester Stonehill Inn 10 Action: explored Phandalin Object: gain more knowledge.
#     - Emoji Representation: Terrill Bloodscar Townmaster’s Hall 10 I talked to Terrill Bloodscar Object at Townmasters Hall
#     - Emoji Representation: Conrad Scarface Phandalin Town Square 10 Action  action.action, action.action  Action, action.action  action, action.action  action, action.action  action, action.action  action, action.action
#     - Emoji Representation: Nellie Starsmith Lionshield Coster 10 I rejected danger and thwarted the heiress
#     - Emoji Representation: Valerie Grinblade Tresendar Manor 10 Action: reached the upper chamber; Object: explored, upper chamber.
# Toblen Stonehill Stonehill Inn 11 Toblen Stonehill worked tirelessly to promote the goods in Stonehill Inn. He took advantage of the current market conditions and took advantage of locals curiosity. He was inspired by Conrad Scarfaces image, and built an impressive store to sell his goods.
# Daran Edermath Phandalin Miner's Exchange 11 I was looking to set up a positive connection to meet and connect with a friend from Lionshield County. I will make a journey to the nearby stream, get to know everyone else and then enjoy the local trails. I know I had met someone before and they shared my interests, so I wasnt sure if I could find a friend. Upon my return home, I will make sure I am still looking for friends, even if they werent new.
# Linene Graywind Townmaster’s Hall 11 Linne Graywind had been in Phandalin Miner’s Exchange. I had asked her to shop there tomorrow. This was a new trading post near Townmaster’s Hall, which was home to a diverse store offering goods and services.
# Halia Thornton Lionshield Coster 11 You established Phandalin Miners Exchange as closest thing to governing authority. Meeting Qelline Alderleaf, investigating the towns troubles and finding solutions.
# Qelline Alderleaf Lionshield Coster 11 Hello, I have been staying in the Stonehill Inn to make sure everyone was in before a fight develops.
# Sister Garaele Tresendar Manor 11 I plan to explore Phandalin, build a strong alliance with Harbin Wester, and learn about their culture and traditions in order to build a strong alliance with Terrill Bloodscar.
# Harbin Wester Barthen's Provisions 11 I planned to explore Phandalin.
# Terrill Bloodscar Phandalin Miner's Exchange 11 I used to be Terrill Bloodscar: A mission to rob innocent people.
# Conrad Scarface Stonehill Inn 11 Toblen Stonehill and I were at Stonehill Inn, meeting Conrad Scarface and Toblen Stonehill.
# Nellie Starsmith Tresendar Manor 11 I was in Tresendar Manor.
# Valerie Grinblade Edermath Orchard 11 She returned to the Edermath Orchard tomorrow and joined the gang.
#     - Emoji Representation: Toblen Stonehill Stonehill Inn 11 action, Object action => Toblen Stonehill worked tirelessly to promote the goods in Stonehill Inn .. . He took advantage of the current market conditions and took advantage of locals curiosity . dll, product => Streetstones, store => Sell his goods at Stonehill Inn. . dll, action => Toblen Stonehill worked tirelessly to promote the goods in Stonehill Inn .. . He took advantage of the current market conditions and took advantage of locals curiosity .. . He was inspired by Conrad Scarfaces image .. . . . Building an impressive store to sell his goods  Action => Toblen
#     - Emoji Representation: Daran Edermath Phandalin Miner's Exchange 11 Action: Set up positive connection Action: Meet, connect with Friend from Lionshield County Action: Find new friends Upon my return home Action: Keep looking for new friends Object: Make sure I am still looking for friends, even if they werent new
#     - Emoji Representation: Linene Graywind Townmaster’s Hall 11 Action (Shop(Object)) Task (Action (Donated)) Reply (Clarence Graywind)
#     - Emoji Representation: Halia Thornton Lionshield Coster 11 Phandalin Miners Exchange  Meeting Qelline Alderleaf  Investigating the town troubles  Finding solutions
#     - Emoji Representation: Qelline Alderleaf Lionshield Coster 11 Greetings, Stonehill Inn Action
#     - Emoji Representation: Sister Garaele Tresendar Manor 11 Action: Explore Phandalin, Build An alliance with Harbin Wester, Learn about their culture and traditions To build a strong alliance with Terrill Bloodscar Action: Create an alliance with Terrill Bloodscar. Object: Explore Phandalin
#     - Emoji Representation: Harbin Wester Barthen's Provisions 11 [Action, Object] [I planned to explore Phandalin.]
#     - Emoji Representation: Terrill Bloodscar Phandalin Miner's Exchange 11 Action: I used to be Terrill Bloodscar: A mission to rob innocent people. Object: I
#     - Emoji Representation: Conrad Scarface Stonehill Inn 11 Action: met Toblen Stonehill Object: Conrad Scarface.
#     - Emoji Representation: Nellie Starsmith Tresendar Manor 11 Action  I was in Tresendar Manor  I was
#     - Emoji Representation: Valerie Grinblade Edermath Orchard 11 She returned to the Edermath Orchard tomorrow and joined the gang.
# Toblen Stonehill Lionshield Coster 12 Toblen Stonehill: I will begin selling all the goods in the trading post to the people of the town. Halia Thornton: I will discuss trading strategies with Toblen Stonehill. Terrill Bloodscar: I will have nothing better to do.
# Daran Edermath Phandalin Town Square 12 Qelline Alderleaf and Daran Edermath will meet up in Phandalin Town Square. Daran should join them in their discussions. They may also try to pass around a message posed by the person they wanted to meet. Daran should also try to get their contact information and let them know if they can stay nearby.
# Linene Graywind Barthen's Provisions 12 Lynne Graywind: At the same time, I plan to shop in Phandalin tomorrow, considering the potential for a deadly and unwarranted robbery in town. I will be exploring the many shops in Phandalin.
# Halia Thornton Lionshield Coster 12 After researching, Thornton was determined to build Phandalin Miners Exchange as the closest governing authority. She was meeting with Toblen Stonehill to discuss her plan and get the word out to the local miners. The trade post is a perfect opportunity to reshape the town and ensure stability and growth. Thornton outlines her mission to establish Phandalin Miners Exchange as the closest thing to a governing authority. Toblen suggests taking her advice on how to halt the banditry, while Thornton speaks up to show her dedication to the project. He is proud to support Halias ambitious plans and will use the opportunity to help her with the project.
# Qelline Alderleaf Phandalin Town Square 12 Qelline Alderleaf had said to Qelline.
# Sister Garaele Shrine of Luck 12 I had begun my mission to gain insight into the culture and traditions of Phandalin.
# Harbin Wester Townmaster’s Hall 12 Harbin Wester  explained his plans for Phandalin, while Valerie Grinblade provided advice. They talked about the risks of robbery and the needs in maintaining records.
# Terrill Bloodscar Lionshield Coster 12 I will rob innocent people in Lionshield Coster today.
# Conrad Scarface Phandalin Town Square 12 In the next hour, I had planned to travel to the Stonehill Inn to catch a glimpse of the Redbrand ruffians in action.
# Nellie Starsmith Phandalin Miner's Exchange 12 It might be best to take a break and explore the new area around Phandalin Miners Exchange. I will start by observing Nellie Starsmiths activities. Nellie Starsmith is an ambitious and calculating human woman named Halia Thornton, who has been working diligently to create a counter-terrorist group. When she gets back, she will use her ruffian and powerful robes to rob and kill adventurers.
# Valerie Grinblade Townmaster’s Hall 12 Valerie Grinblade: - I was the first to know about any new orc threats. We took on dangerous orcs that stood within the towns boundaries.
#     - Emoji Representation: Toblen Stonehill Lionshield Coster 12 - Toblen Stonehill -Halia Thornton -Trading strategies -Terrill Bloodscar
#     - Emoji Representation: Daran Edermath Phandalin Town Square 12 Qelline Alderleaf RETURN, Daran Edermath (B) Join them (C) pass/pass around/contact info (D) join them.
#     - Emoji Representation: Linene Graywind Barthen's Provisions 12 Object: shopping Object: consider potential for robbery Potential: deadly and unwarranted Robbery: not, shop ### Object: Phandalin
#     - Emoji Representation: Halia Thornton Lionshield Coster 12 KEY TRANSFER [THROUNTTON, TOBELN Stonehill] Object: Phandalin Miners Exchange
#     - Emoji Representation: Qelline Alderleaf Phandalin Town Square 12 [Page](Action): Qelline Alderleaf said to Qelline. It returns Object[Action:](Qelline Alderleaf)(Nothing)
#     - Emoji Representation: Sister Garaele Shrine of Luck 12 Action: had begun Mission: to gain insight into the culture and traditions of Phandalin Object: insight
#     - Emoji Representation: Harbin Wester Townmaster’s Hall 12 Action: Explain plan Object: Phandalin, Advice Answer: Notify Valerie Grinblade Object: Talk about risks of robbery Action: Discuss, Keep records Act: Keep records
#     - Emoji Representation: Terrill Bloodscar Lionshield Coster 12 Action -- Rob innocent people in Lionshield Coster Object -- It is not a criminal act.
#     - Emoji Representation: Conrad Scarface Phandalin Town Square 12 Action: plan, object: Stonehill Inn
#     - Emoji Representation: Nellie Starsmith Phandalin Miner's Exchange 12 Slave, Action Observe, Object nellie starsmith, rob adventurers, act as counter-terrorists, use ruffian and powerful robes.
#     - Emoji Representation: Valerie Grinblade Townmaster’s Hall 12 tuple [I was the first to know about any new orc threats]
